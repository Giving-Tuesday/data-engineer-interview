# %%
import pandas as pd

# %% [markdown]
# # Provider 1

# %%
df1 = pd.read_csv('../data_lake/raw/2023/05/provider1_volunteering_data.csv')
df1.head()
# Out:
#     volunteer_id  org_id       date  hours
# 0  768396c6-10e9    9330  18/2/2021      5
# 1  76839a18-10e9    2465  20/9/2021      2
# 2  76839bb2-10e9    9269  11/9/2022      4
# 3  76839b9e-10e9      86  30/1/2022      7
# 4  76839b3a-10e9    7026   2/6/2016      1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   volunteer_id  423 non-null    object
#  1   org_id        423 non-null    int64
#  2   date          423 non-null    object
#  3   hours         423 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 13.3+ KB

# %%
df1['date'] = pd.to_datetime(df1.date)
df1.date
# Out:
# /var/folders/bd/2fcpz2_95037mnw19_r21ybw0000gn/T/ipykernel_15555/131024191.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['date'] = pd.to_datetime(df1.date)
# 0     2021-02-18
# 1     2021-09-20
# 2     2022-09-11
# 3     2022-01-30
# 4     2016-06-02
#          ...
# 418   2017-09-26
# 419   2022-09-15
# 420   2022-02-07
# 421   2021-08-21
# 422   2019-01-02
# Name: date, Length: 423, dtype: datetime64[ns]

# %% [markdown]
# # Provider 2

# %%
df2 = pd.read_csv('../data_lake/raw/2023/05/provider2_volunteering_data.csv')
df2.head()
# Out:
#   volunteer_id      org_id        date  hours
# 0   A4RWNF29UP  A0MLEV9LBZ   2/17/2019      7
# 1   U5F15SH2RF  3AMHKX1TDX   8/28/2019      2
# 2   S7NGZTVGE8  N3HB23HN5J  11/29/2018      7
# 3   3CK2SE7E3M  0G6CRVHLVP    5/2/2023      6
# 4   BV5PEWNV2M  0J7J0AV6G0   9/16/2020      3

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   volunteer_id  368 non-null    object
#  1   org_id        368 non-null    object
#  2   date          368 non-null    object
#  3   hours         368 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 11.6+ KB

# %%
df2['date'] = pd.to_datetime(df2.date)
df2.date
# Out:
# 0     2019-02-17
# 1     2019-08-28
# 2     2018-11-29
# 3     2023-05-02
# 4     2020-09-16
#          ...
# 363   2019-12-04
# 364   2020-02-21
# 365   2019-10-15
# 366   2021-01-05
# 367   2023-01-06
# Name: date, Length: 368, dtype: datetime64[ns]

# %% [markdown]
# # Provider 3

# %%
df3 = pd.read_csv('../data_lake/raw/2023/05/provider3_volunteering_data.csv')
df3.head()
# Out:
#    volunteer_id                    type  org_id        date  hours
# 0           220        Leisure & Sports     217  2022/11/16      2
# 1           211              Healthcare     149  2019/04/12      4
# 2           241              Healthcare      71  2022/04/25      2
# 3           166  Pet and Animal Service     120  2021/02/01      2
# 4            42              Healthcare      59  2021/12/15      4

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   volunteer_id  764 non-null    int64
#  1   type          764 non-null    object
#  2   org_id        764 non-null    int64
#  3   date          764 non-null    object
#  4   hours         764 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 30.0+ KB

# %%
df3 = df3.drop(columns=['type'])

# %% [markdown]
# # Combine all into one table

# %%
df_all = pd.concat([df1, df2, df3], ignore_index=True)

# %%
df_all.head()
# Out:
#     volunteer_id org_id                 date  hours
# 0  768396c6-10e9   9330  2021-02-18 00:00:00      5
# 1  76839a18-10e9   2465  2021-09-20 00:00:00      2
# 2  76839bb2-10e9   9269  2022-09-11 00:00:00      4
# 3  76839b9e-10e9     86  2022-01-30 00:00:00      7
# 4  76839b3a-10e9   7026  2016-06-02 00:00:00      1

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   volunteer_id  1555 non-null   object
#  1   org_id        1555 non-null   object
#  2   date          1555 non-null   object
#  3   hours         1555 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 48.7+ KB

# %%
df_all.to_csv('../data_lake/curated/2023/05/all_volunteering_data.csv', index=False)
